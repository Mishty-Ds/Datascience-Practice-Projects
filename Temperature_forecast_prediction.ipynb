# %%
#Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
weather_df=pd.read_csv("temperature.csv")

# %%
weather_df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
weather_df.shape
# Out:
# (7752, 25)

# %%
weather_df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %%
#Data preprocessing and visualization

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
weather_df.isnull().any()
# Out:
# station              True
# Date                 True
# Present_Tmax         True
# Present_Tmin         True
# LDAPS_RHmin          True
# LDAPS_RHmax          True
# LDAPS_Tmax_lapse     True
# LDAPS_Tmin_lapse     True
# LDAPS_WS             True
# LDAPS_LH             True
# LDAPS_CC1            True
# LDAPS_CC2            True
# LDAPS_CC3            True
# LDAPS_CC4            True
# LDAPS_PPT1           True
# LDAPS_PPT2           True
# LDAPS_PPT3           True
# LDAPS_PPT4           True
# lat                 False
# lon                 False
# DEM                 False
# Slope               False
# Solar radiation     False
# Next_Tmax            True
# Next_Tmin            True
# dtype: bool

# %%
weather_df.dropna()
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7745     21.0  30-08-2017          23.1          17.8    24.688997
# 7746     22.0  30-08-2017          22.5          17.4    30.094858
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936  6.818887   69.451805
# ...

# %%
#To check for the missing values again
weather_df.isnull().any()
# Out:
# station              True
# Date                 True
# Present_Tmax         True
# Present_Tmin         True
# LDAPS_RHmin          True
# LDAPS_RHmax          True
# LDAPS_Tmax_lapse     True
# LDAPS_Tmin_lapse     True
# LDAPS_WS             True
# LDAPS_LH             True
# LDAPS_CC1            True
# LDAPS_CC2            True
# LDAPS_CC3            True
# LDAPS_CC4            True
# LDAPS_PPT1           True
# LDAPS_PPT2           True
# LDAPS_PPT3           True
# LDAPS_PPT4           True
# lat                 False
# lon                 False
# DEM                 False
# Slope               False
# Solar radiation     False
# Next_Tmax            True
# Next_Tmin            True
# dtype: bool

# %%
weather_df = weather_df.dropna()

# %%
#drop the columns with null values
weather_df.isnull().any()
# Out:
# station             False
# Date                False
# Present_Tmax        False
# Present_Tmin        False
# LDAPS_RHmin         False
# LDAPS_RHmax         False
# LDAPS_Tmax_lapse    False
# LDAPS_Tmin_lapse    False
# LDAPS_WS            False
# LDAPS_LH            False
# LDAPS_CC1           False
# LDAPS_CC2           False
# LDAPS_CC3           False
# LDAPS_CC4           False
# LDAPS_PPT1          False
# LDAPS_PPT2          False
# LDAPS_PPT3          False
# LDAPS_PPT4          False
# lat                 False
# lon                 False
# DEM                 False
# Slope               False
# Solar radiation     False
# Next_Tmax           False
# Next_Tmin           False
# dtype: bool

# %%
#Correlation Matrix

# %%
plt.figure(figsize=(20,10))
sns.heatmap(weather_df.corr(),cmap='coolwarm',annot=True)

# %%
#Visualizations

# %%
plt.figure(figsize=(12,5))
plt.title("Maximum Temperature Distirbution Graph")
ax = sns.distplot(weather_df["Next_Tmax"], color = 'g')

# %%
#Maximum temperature is around 30

# %%
plt.figure(figsize=(12,5))
plt.title("Minimum Temperature Distirbution Graph")
ax = sns.distplot(weather_df["Next_Tmin"], color = 'g')

# %%
#Min temperature is around 23

# %%
#Lets visualise Next_Tmax and Next_Tmin over other dimensions

# %%
#visualisation over time

# %%
dategroup=weather_df.groupby('Date').mean()
plt.figure(figsize=(30,10))
dategroup['Next_Tmax'].plot(x=weather_df.Date)
plt.title('Average Max Temperature')
# Out:
# Text(0.5, 1.0, 'Average Max Temperature')

# %%
#Mean  MAX temperature is around 30

# %%
dategroup=weather_df.groupby('Date').mean()
plt.figure(figsize=(30,10))
dategroup['Next_Tmin'].plot(x=weather_df.Date)
plt.title('Average Min Temperature')
# Out:
# Text(0.5, 1.0, 'Average Min Temperature')

# %%
#Mean Min temperature is around 23

# %%
weather_df['station'].value_counts()
# Out:
# 25.0    307
# 18.0    307
# 2.0     307
# 17.0    307
# 10.0    307
# 23.0    307
# 3.0     306
# 4.0     306
# 13.0    305
# 16.0    304
# 20.0    304
# 21.0    304
# 14.0    303
# 1.0     303
# 15.0    302
# 12.0    302
# 22.0    302
# 9.0     302
# 24.0    302
# 19.0    302
# 11.0    301
# 7.0     301
# 6.0     301
# 8.0     300
# 5.0     296
# Name: station, dtype: int64

# %%
sns.barplot(x='station', y='Next_Tmax', data=weather_df)

# %%
sns.barplot(x='station', y='Next_Tmin', data=weather_df)

# %%
#No major takeaways rather than being able to see that the average min temp is around 23 and max is around 30

# %%
#Model building

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
weather_df = weather_df.apply(LabelEncoder().fit_transform)

# %%
y = weather_df["Next_Tmax"]

# %%
z=weather_df["Next_Tmin"]

# %%
x = weather_df.drop(["Next_Tmax","Next_Tmin"], axis = 1)

# %%
x
# Out:
#       station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0           0   288            80            73         4400         4391
# 1           1   288           112            75         3224         4136
# 2           2   288           109            92         2450         1835
# 3           3   288           113            93         4396         6863
# 4           4   288           107            78         4005         3951
# ...       ...   ...           ...           ...          ...          ...
# 7745       20   302            24            37           18          813
# 7746       21   302            18            33          115         1781
# 7747       22   302            26            30           43          895
# 7748       23   302            26            36           14          678
# 7749       24   302            25            33           12          667
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  ...  LDAPS_CC4  \
# ...

# %%
z
# Out:
# 0        75
# 1        88
# 2       102
# 3       106
# 4        88
#        ...
# 7745     40
# 7746     34
# 7747     44
# 7748     51
# 7749     37
# Name: Next_Tmin, Length: 7588, dtype: int64

# %%
y
# Out:
# 0        92
# 1       106
# 2       112
# 3       118
# 4       113
#        ...
# 7745     77
# 7746     81
# 7747     84
# 7748     87
# 7749     79
# Name: Next_Tmax, Length: 7588, dtype: int64

# %%
#deviding data into training and testing sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
x_train,x_test,z_train,z_test=train_test_split(x,z,test_size=0.20,random_state=42)

# %%
#importing decision tree model 
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)
classifier.fit(x,y)

classifier_z=DecisionTreeClassifier(criterion='entropy',random_state=0)
classifier_z.fit(x,z)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
#predicting values for x_test and compairing result with y_test
print("Next_tmax:-")
y_pred=classifier.predict(x_test)
print("predicted values:-")
print(y_pred.astype(int))
y_test_arr=np.array(y_test)
print("original values:-")
print(y_test_arr)
# Out:
# Next_tmax:-
# predicted values:-
# [ 88  79 137 ... 101  21  60]
# original values:-
# [ 88  79 137 ... 101  21  60]

# %%
#predicting values for x_test and compairing result with z_test
print("Next_Tmin:-")
z_pred=classifier_z.predict(x_test)
print("predicted values:-")
print(z_pred.astype(int))
z_test_arr=np.array(z_test)
print("original values:-")
print(z_test_arr)
# Out:
# Next_Tmin:-
# predicted values:-
# [108  78 110 ...  73  56  64]
# original values:-
# [108  78 110 ...  73  56  64]

# %%
from sklearn.metrics import accuracy_score

# %%
#cheaking accuracy of our model
accuracy=accuracy_score(y_pred,y_test)
print("{}%".format(accuracy*100))

accuracy=accuracy_score(z_pred,z_test)
print("{}%".format(accuracy*100))
# Out:
# 100.0%
# 100.0%

# %%
#Linear regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
regressor2 = LinearRegression()

# %%
regressor2.fit(x_train, z_train)
# Out:
# LinearRegression()

# %%
#predicting values for x_test and compairing result with y_test
print("Next_tmax:-")
y_pred=regressor.predict(x_test)
print("predicted values:-")
print(y_pred.astype(int))
y_test_arr=np.array(y_test)
print("original values:-")
print(y_test_arr)
# Out:
# Next_tmax:-
# predicted values:-
# [ 74  53 132 ... 102  59  90]
# original values:-
# [ 88  79 137 ... 101  21  60]

# %%
#predicting values for x_test and compairing result with z_test
print("Next_Tmin:-")
z_pred=regressor2.predict(x_test)
print("predicted values:-")
print(z_pred.astype(int))
z_test_arr=np.array(z_test)
print("original values:-")
print(z_test_arr)
# Out:
# Next_Tmin:-
# predicted values:-
# [104  74 105 ...  66  60  84]
# original values:-
# [108  78 110 ...  73  56  64]

# %%
from sklearn.metrics import mean_absolute_error, median_absolute_error

# %%
# make a prediction set using the test set
prediction = regressor.predict(x_test)

# Evaluate the prediction accuracy of the model 
print('The Explained Variance: %.2f' % regressor.score(x_test, y_test))
print('The Mean Absolute Error: %.2f degrees celcius' % mean_absolute_error(
    y_test, prediction))
print('The Median Absolute Error: %.2f degrees celcius' %
      median_absolute_error(y_test, prediction))
# Out:
# The Explained Variance: 0.75
# The Mean Absolute Error: 11.82 degrees celcius
# The Median Absolute Error: 9.64 degrees celcius

# %%
# make a prediction set using the test set
prediction = regressor2.predict(x_test)

# Evaluate the prediction accuracy of the model 
print('The Explained Variance: %.2f' % regressor.score(x_test, z_test))
print('The Mean Absolute Error: %.2f degrees celcius' % mean_absolute_error(
    z_test, prediction))
print('The Median Absolute Error: %.2f degrees celcius' %
      median_absolute_error(z_test, prediction))
# Out:
# The Explained Variance: -0.02
# The Mean Absolute Error: 8.21 degrees celcius
# The Median Absolute Error: 6.72 degrees celcius

# %%
from sklearn.ensemble import RandomForestRegressor
rdr = RandomForestRegressor()
rdr.fit(x_train,y_train)
pred=rdr.predict(x_test)

# %%
rdr2=RandomForestRegressor()
rdr2.fit(x_train,z_train)
# Out:
# RandomForestRegressor()

# %%
pred2=rdr2.predict(x_test)

# %%
# Evaluate the prediction accuracy of the model 
print('The Explained Variance: %.2f' % rdr.score(x_test, y_test))
print('The Mean Absolute Error: %.2f degrees celcius' % mean_absolute_error(
    y_test, pred))
print('The Median Absolute Error: %.2f degrees celcius' %
      median_absolute_error(y_test, pred))
# Out:
# The Explained Variance: 0.90
# The Mean Absolute Error: 10.81 degrees celcius
# The Median Absolute Error: 8.00 degrees celcius

# %%
print('The Explained Variance: %.2f' % rdr2.score(x_test, z_test))
print('The Mean Absolute Error: %.2f degrees celcius' % mean_absolute_error(
    z_test, pred2))
print('The Median Absolute Error: %.2f degrees celcius' %
      median_absolute_error(z_test, pred2))
# Out:
# The Explained Variance: 0.90
# The Mean Absolute Error: 23.26 degrees celcius
# The Median Absolute Error: 21.00 degrees celcius

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred=dtr.predict(x_test)

# %%
dtr2=DecisionTreeRegressor()
dtr2.fit(x_train,z_train)
pred2=dtr.predict(x_test)

# %%
print('The Explained Variance: %.2f' % dtr.score(x_test, y_test))
print('The Mean Absolute Error: %.2f degrees celcius' % mean_absolute_error(
    y_test, pred))
print('The Median Absolute Error: %.2f degrees celcius' %
      median_absolute_error(y_test, pred))
# Out:
# The Explained Variance: 0.76
# The Mean Absolute Error: 10.81 degrees celcius
# The Median Absolute Error: 8.00 degrees celcius

# %%
print('The Explained Variance: %.2f' % dtr2.score(x_test, z_test))
print('The Mean Absolute Error: %.2f degrees celcius' % mean_absolute_error(
    z_test, pred2))
print('The Median Absolute Error: %.2f degrees celcius' %
      median_absolute_error(z_test, pred2))
# Out:
# The Explained Variance: 0.78
# The Mean Absolute Error: 23.26 degrees celcius
# The Median Absolute Error: 21.00 degrees celcius

# %%
#Model Saving 
import pickle
filename='Temperature_prediction.pkl'
pickle.dump(classifier,open(filename,'wb'))
